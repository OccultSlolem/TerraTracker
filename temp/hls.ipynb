# %%
# LP DAAC HLS API
# LP DAAC = Land Processes Distributed Active Archive Center
# HLS = Harmonized Landsat Sentinel-2

import requests as r

stac = "https://cmr.earthdata.nasa.gov/stac/"
stac_response = r.get(stac).json()
for s in stac_response: print(s)
# Out:
# id
# title
# stac_version
# type
# description
# links

# %%
stac_lp = [s for s in stac_response['links'] if 'LP' in s['title']] # LP catalogs
for s in stac_lp: print(s)
# Out:
# {'title': 'LPDAAC_ECS', 'rel': 'child', 'type': 'application/json', 'href': 'https://cmr.earthdata.nasa.gov/stac/LPDAAC_ECS'}
# {'title': 'LPCUMULUS', 'rel': 'child', 'type': 'application/json', 'href': 'https://cmr.earthdata.nasa.gov/stac/LPCUMULUS'}
# {'title': 'LPCLOUD', 'rel': 'child', 'type': 'application/json', 'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD'}

# %%
lp_cloud = r.get([s for s in stac_lp if s['title'] == 'LPCLOUD'][0]['href']).json()
for l in lp_cloud: print(f"{l}: {lp_cloud[l]}")

# if rel['next'] exists we need to recursively call the next page
# if rel['next'] does not exist we are on the last page
def get_page(url, page=1):
    print (f"PAGE {page}")
    response = r.get(url).json()
    response_links = response['links']
    for l in response_links:
        print(f"{l['rel']}: {l['href']}")
    
    last_link = response_links[-1]
    print()

    if 'next' in last_link['rel']:
        get_page(last_link['href'], page + 1)
    else:
        print("Last page")

print()
print()
get_page(lp_cloud['links'][0]['href'])
# Out:
# id: LPCLOUD
# title: LPCLOUD
# description: Root catalog for LPCLOUD
# type: Catalog
# stac_version: 1.0.0
# links: [{'rel': 'self', 'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD', 'title': 'Provider catalog', 'type': 'application/json'}, {'rel': 'root', 'href': 'https://cmr.earthdata.nasa.gov/stac/', 'title': 'Root catalog', 'type': 'application/json'}, {'rel': 'collections', 'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections', 'title': 'Provider Collections', 'type': 'application/json'}, {'rel': 'search', 'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/search', 'title': 'Provider Item Search', 'type': 'application/geo+json', 'method': 'GET'}, {'rel': 'search', 'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/search', 'title': 'Provider Item Search', 'type': 'application/geo+json', 'method': 'POST'}, {'rel': 'conformance', 'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/conformance', 'title': 'Conformance Classes', 'type': 'application/geo+json'}, {'rel': 'service-desc', 'href': 'https://api.stacspec.org/v1.0.0-beta.1/openapi.yaml', 'title': 'OpenAPI Doc', 'type': 'application/vnd.oai.openapi;version=3.0'}, {'rel': 'service-doc', 'href': 'https://api.stacspec.org/v1.0.0-beta.1/index.html', 'title': 'HTML documentation', 'type': 'text/html'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ASTGTM_NUMNC.v003', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ASTGTM_NC.v003', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ASTGTM.v003', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/WaterBalance_Daily_Historical_GRIDMET.v1.5', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L2G_CLOUD.v002', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L2G_LSTE.v002', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L1CG_RAD.v002', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L1B_ATT.v002', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L2_CLOUD.v002', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L1B_GEO.v002', 'type': 'application/json'}, {'rel': 'next', 'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD?page=2'}]
# conformsTo: ['https://api.stacspec.org/v1.0.0-beta.1/core', 'https://api.stacspec.org/v1.0.0-beta.1/item-search', 'https://api.stacspec.org/v1.0.0-beta.1/item-search#fields', 'https://api.stacspec.org/v1.0.0-beta.1/item-search#query', 'https://api.stacspec.org/v1.0.0-beta.1/item-search#sort', 'https://api.stacspec.org/v1.0.0-beta.1/item-search#context', 'http://www.opengis.net/spec/ogcapi-features-1/1.0/conf/core', 'http://www.opengis.net/spec/ogcapi-features-1/1.0/conf/oas30', 'http://www.opengis.net/spec/ogcapi-features-1/1.0/conf/geojson']
#
#
# PAGE 1
# self: https://cmr.earthdata.nasa.gov/stac/LPCLOUD
# root: https://cmr.earthdata.nasa.gov/stac/
# collections: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections
# search: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/search
# search: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/search
# conformance: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/conformance
# service-desc: https://api.stacspec.org/v1.0.0-beta.1/openapi.yaml
# service-doc: https://api.stacspec.org/v1.0.0-beta.1/index.html
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ASTGTM_NUMNC.v003
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ASTGTM_NC.v003
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ASTGTM.v003
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/WaterBalance_Daily_Historical_GRIDMET.v1.5
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L2G_CLOUD.v002
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L2G_LSTE.v002
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L1CG_RAD.v002
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L1B_ATT.v002
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L2_CLOUD.v002
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L1B_GEO.v002
# next: https://cmr.earthdata.nasa.gov/stac/LPCLOUD?page=2
#
# PAGE 2
# self: https://cmr.earthdata.nasa.gov/stac/LPCLOUD
# root: https://cmr.earthdata.nasa.gov/stac/
# collections: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections
# search: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/search
# search: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/search
# conformance: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/conformance
# service-desc: https://api.stacspec.org/v1.0.0-beta.1/openapi.yaml
# service-doc: https://api.stacspec.org/v1.0.0-beta.1/index.html
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L2_LSTE.v002
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L1B_RAD.v002
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L2T_LSTE.v002
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L1CT_RAD.v002
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/EMITL1BRAD.v001
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/EMITL1BATT.v001
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/EMITL2ARFL.v001
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/EMITL2BCH4PLM.v001
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/EMITL2BMIN.v001
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/EMITL2BCH4ENH.v001
# prev: https://cmr.earthdata.nasa.gov/stac/LPCLOUD?page=1
# next: https://cmr.earthdata.nasa.gov/stac/LPCLOUD?page=3
#
# PAGE 3
# self: https://cmr.earthdata.nasa.gov/stac/LPCLOUD
# root: https://cmr.earthdata.nasa.gov/stac/
# collections: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections
# search: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/search
# search: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/search
# conformance: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/conformance
# service-desc: https://api.stacspec.org/v1.0.0-beta.1/openapi.yaml
# service-doc: https://api.stacspec.org/v1.0.0-beta.1/index.html
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/EMITL3ASA.v001
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30.v2.0
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSS30.v2.0
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD17A2H.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD17A2HGF.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD21.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD21C2.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD21A2.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD21C1.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD21A1D.v061
# prev: https://cmr.earthdata.nasa.gov/stac/LPCLOUD?page=2
# next: https://cmr.earthdata.nasa.gov/stac/LPCLOUD?page=4
#
# PAGE 4
# self: https://cmr.earthdata.nasa.gov/stac/LPCLOUD
# root: https://cmr.earthdata.nasa.gov/stac/
# collections: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections
# search: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/search
# search: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/search
# conformance: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/conformance
# service-desc: https://api.stacspec.org/v1.0.0-beta.1/openapi.yaml
# service-doc: https://api.stacspec.org/v1.0.0-beta.1/index.html
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD21A1N.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD21C3.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD11_L2.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD11C2.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD11A2.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD11B2.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD11C1.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD11A1.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD11B1.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD11C3.v061
# prev: https://cmr.earthdata.nasa.gov/stac/LPCLOUD?page=3
# next: https://cmr.earthdata.nasa.gov/stac/LPCLOUD?page=5
#
# PAGE 5
# self: https://cmr.earthdata.nasa.gov/stac/LPCLOUD
# root: https://cmr.earthdata.nasa.gov/stac/
# collections: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections
# search: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/search
# search: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/search
# conformance: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/conformance
# service-desc: https://api.stacspec.org/v1.0.0-beta.1/openapi.yaml
# service-doc: https://api.stacspec.org/v1.0.0-beta.1/index.html
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD11B3.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD15A2H.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD16A2.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD16A2GF.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD16A3GF.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD17A3HGF.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD09Q1.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD09A1.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD09GA.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD09GQ.v061
# prev: https://cmr.earthdata.nasa.gov/stac/LPCLOUD?page=4
# next: https://cmr.earthdata.nasa.gov/stac/LPCLOUD?page=6
#
# PAGE 6
# self: https://cmr.earthdata.nasa.gov/stac/LPCLOUD
# root: https://cmr.earthdata.nasa.gov/stac/
# collections: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections
# search: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/search
# search: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/search
# conformance: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/conformance
# service-desc: https://api.stacspec.org/v1.0.0-beta.1/openapi.yaml
# service-doc: https://api.stacspec.org/v1.0.0-beta.1/index.html
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD09CMG.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD14.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD14A2.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD14A1.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD13C1.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD13A2.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD13Q1.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD13A1.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD13C2.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD13A3.v061
# prev: https://cmr.earthdata.nasa.gov/stac/LPCLOUD?page=5
# next: https://cmr.earthdata.nasa.gov/stac/LPCLOUD?page=7
#
# PAGE 7
# self: https://cmr.earthdata.nasa.gov/stac/LPCLOUD
# root: https://cmr.earthdata.nasa.gov/stac/
# collections: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections
# search: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/search
# search: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/search
# conformance: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/conformance
# service-desc: https://api.stacspec.org/v1.0.0-beta.1/openapi.yaml
# service-doc: https://api.stacspec.org/v1.0.0-beta.1/index.html
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD28C2.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD28C3.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MOD17A2H.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MOD17A2HGF.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MOD21.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MOD21C2.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MOD21A2.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MOD21C1.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MOD21A1D.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MOD21A1N.v061
# prev: https://cmr.earthdata.nasa.gov/stac/LPCLOUD?page=6
# next: https://cmr.earthdata.nasa.gov/stac/LPCLOUD?page=8
#
# PAGE 8
# self: https://cmr.earthdata.nasa.gov/stac/LPCLOUD
# root: https://cmr.earthdata.nasa.gov/stac/
# collections: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections
# search: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/search
# search: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/search
# conformance: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/conformance
# service-desc: https://api.stacspec.org/v1.0.0-beta.1/openapi.yaml
# service-doc: https://api.stacspec.org/v1.0.0-beta.1/index.html
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MOD21C3.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MOD11_L2.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MOD11C2.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MOD11A2.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MOD11B2.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MOD11C1.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MOD11A1.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MOD11B1.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MOD11C3.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MOD11B3.v061
# prev: https://cmr.earthdata.nasa.gov/stac/LPCLOUD?page=7
# next: https://cmr.earthdata.nasa.gov/stac/LPCLOUD?page=9
#
# PAGE 9
# self: https://cmr.earthdata.nasa.gov/stac/LPCLOUD
# root: https://cmr.earthdata.nasa.gov/stac/
# collections: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections
# search: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/search
# search: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/search
# conformance: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/conformance
# service-desc: https://api.stacspec.org/v1.0.0-beta.1/openapi.yaml
# service-doc: https://api.stacspec.org/v1.0.0-beta.1/index.html
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MOD15A2H.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MOD16A2.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MOD16A2GF.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MOD16A3GF.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MOD17A3HGF.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MOD09Q1.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MOD09A1.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MOD09GA.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MOD09GQ.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MOD14.v061
# prev: https://cmr.earthdata.nasa.gov/stac/LPCLOUD?page=8
# next: https://cmr.earthdata.nasa.gov/stac/LPCLOUD?page=10
#
# PAGE 10
# self: https://cmr.earthdata.nasa.gov/stac/LPCLOUD
# root: https://cmr.earthdata.nasa.gov/stac/
# collections: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections
# search: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/search
# search: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/search
# conformance: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/conformance
# service-desc: https://api.stacspec.org/v1.0.0-beta.1/openapi.yaml
# service-doc: https://api.stacspec.org/v1.0.0-beta.1/index.html
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MOD14A2.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MOD14A1.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MOD44B.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MOD13C1.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MOD13A2.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MOD13Q1.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MOD13A1.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MOD13C2.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MOD13A3.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MOD28C2.v061
# prev: https://cmr.earthdata.nasa.gov/stac/LPCLOUD?page=9
# next: https://cmr.earthdata.nasa.gov/stac/LPCLOUD?page=11
#
# PAGE 11
# self: https://cmr.earthdata.nasa.gov/stac/LPCLOUD
# root: https://cmr.earthdata.nasa.gov/stac/
# collections: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections
# search: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/search
# search: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/search
# conformance: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/conformance
# service-desc: https://api.stacspec.org/v1.0.0-beta.1/openapi.yaml
# service-doc: https://api.stacspec.org/v1.0.0-beta.1/index.html
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MOD28C3.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD19A2CMG.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD19A3D.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43A3.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43C3.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D42.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D43.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D44.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D45.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D46.v061
# prev: https://cmr.earthdata.nasa.gov/stac/LPCLOUD?page=10
# next: https://cmr.earthdata.nasa.gov/stac/LPCLOUD?page=12
#
# PAGE 12
# self: https://cmr.earthdata.nasa.gov/stac/LPCLOUD
# root: https://cmr.earthdata.nasa.gov/stac/
# collections: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections
# search: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/search
# search: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/search
# conformance: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/conformance
# service-desc: https://api.stacspec.org/v1.0.0-beta.1/openapi.yaml
# service-doc: https://api.stacspec.org/v1.0.0-beta.1/index.html
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D47.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D48.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D50.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D51.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D49.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43A1.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43C1.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D62.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D63.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D64.v061
# prev: https://cmr.earthdata.nasa.gov/stac/LPCLOUD?page=11
# next: https://cmr.earthdata.nasa.gov/stac/LPCLOUD?page=13
#
# PAGE 13
# self: https://cmr.earthdata.nasa.gov/stac/LPCLOUD
# root: https://cmr.earthdata.nasa.gov/stac/
# collections: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections
# search: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/search
# search: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/search
# conformance: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/conformance
# service-desc: https://api.stacspec.org/v1.0.0-beta.1/openapi.yaml
# service-doc: https://api.stacspec.org/v1.0.0-beta.1/index.html
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D65.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D66.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D67.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D68.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43A4.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43C4.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D01.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D04.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D02.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D05.v061
# prev: https://cmr.earthdata.nasa.gov/stac/LPCLOUD?page=12
# next: https://cmr.earthdata.nasa.gov/stac/LPCLOUD?page=14
#
# PAGE 14
# self: https://cmr.earthdata.nasa.gov/stac/LPCLOUD
# root: https://cmr.earthdata.nasa.gov/stac/
# collections: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections
# search: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/search
# search: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/search
# conformance: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/conformance
# service-desc: https://api.stacspec.org/v1.0.0-beta.1/openapi.yaml
# service-doc: https://api.stacspec.org/v1.0.0-beta.1/index.html
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D03.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D06.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D07.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D10.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D13.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D16.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D19.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D25.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D28.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D22.v061
# prev: https://cmr.earthdata.nasa.gov/stac/LPCLOUD?page=13
# next: https://cmr.earthdata.nasa.gov/stac/LPCLOUD?page=15
#
# PAGE 15
# self: https://cmr.earthdata.nasa.gov/stac/LPCLOUD
# root: https://cmr.earthdata.nasa.gov/stac/
# collections: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections
# search: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/search
# search: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/search
# conformance: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/conformance
# service-desc: https://api.stacspec.org/v1.0.0-beta.1/openapi.yaml
# service-doc: https://api.stacspec.org/v1.0.0-beta.1/index.html
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D08.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D11.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D14.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D17.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D20.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D26.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D29.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D23.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D09.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D12.v061
# prev: https://cmr.earthdata.nasa.gov/stac/LPCLOUD?page=14
# next: https://cmr.earthdata.nasa.gov/stac/LPCLOUD?page=16
#
# PAGE 16
# self: https://cmr.earthdata.nasa.gov/stac/LPCLOUD
# root: https://cmr.earthdata.nasa.gov/stac/
# collections: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections
# search: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/search
# search: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/search
# conformance: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/conformance
# service-desc: https://api.stacspec.org/v1.0.0-beta.1/openapi.yaml
# service-doc: https://api.stacspec.org/v1.0.0-beta.1/index.html
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D15.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D18.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D21.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D27.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D30.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D24.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D31.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D32.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D40.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D41.v061
# prev: https://cmr.earthdata.nasa.gov/stac/LPCLOUD?page=15
# next: https://cmr.earthdata.nasa.gov/stac/LPCLOUD?page=17
#
# PAGE 17
# self: https://cmr.earthdata.nasa.gov/stac/LPCLOUD
# root: https://cmr.earthdata.nasa.gov/stac/
# collections: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections
# search: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/search
# search: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/search
# conformance: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/conformance
# service-desc: https://api.stacspec.org/v1.0.0-beta.1/openapi.yaml
# service-doc: https://api.stacspec.org/v1.0.0-beta.1/index.html
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D33.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D34.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D35.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D36.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D37.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D38.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D39.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43A2.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43C2.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D52.v061
# prev: https://cmr.earthdata.nasa.gov/stac/LPCLOUD?page=16
# next: https://cmr.earthdata.nasa.gov/stac/LPCLOUD?page=18
#
# PAGE 18
# self: https://cmr.earthdata.nasa.gov/stac/LPCLOUD
# root: https://cmr.earthdata.nasa.gov/stac/
# collections: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections
# search: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/search
# search: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/search
# conformance: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/conformance
# service-desc: https://api.stacspec.org/v1.0.0-beta.1/openapi.yaml
# service-doc: https://api.stacspec.org/v1.0.0-beta.1/index.html
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D53.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D54.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D55.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D56.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D57.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D58.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D60.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D61.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D59.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD64A1.v061
# prev: https://cmr.earthdata.nasa.gov/stac/LPCLOUD?page=17
# next: https://cmr.earthdata.nasa.gov/stac/LPCLOUD?page=19
#
# PAGE 19
# self: https://cmr.earthdata.nasa.gov/stac/LPCLOUD
# root: https://cmr.earthdata.nasa.gov/stac/
# collections: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections
# search: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/search
# search: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/search
# conformance: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/conformance
# service-desc: https://api.stacspec.org/v1.0.0-beta.1/openapi.yaml
# service-doc: https://api.stacspec.org/v1.0.0-beta.1/index.html
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD18C1.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD19A2.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD12Q2.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD12C1.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD12Q1.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD19A1.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD15A3H.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD15A2H.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD18C2.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD18A2.v061
# prev: https://cmr.earthdata.nasa.gov/stac/LPCLOUD?page=18
# next: https://cmr.earthdata.nasa.gov/stac/LPCLOUD?page=20
#
# PAGE 20
# self: https://cmr.earthdata.nasa.gov/stac/LPCLOUD
# root: https://cmr.earthdata.nasa.gov/stac/
# collections: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections
# search: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/search
# search: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/search
# conformance: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/conformance
# service-desc: https://api.stacspec.org/v1.0.0-beta.1/openapi.yaml
# service-doc: https://api.stacspec.org/v1.0.0-beta.1/index.html
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD18A1.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD19A1CMGL.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD19A1CMGO.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD19A3CMG.v061
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/WaterBalance_Monthly_Historical_GRIDMET.v1.5
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/OPERA_L3_DIST-ALERT-HLS_PROVISIONAL_V0.v0
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VJ121.v002
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VJ121C2.v002
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VJ121A2.v002
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VJ121C1.v002
# prev: https://cmr.earthdata.nasa.gov/stac/LPCLOUD?page=19
# next: https://cmr.earthdata.nasa.gov/stac/LPCLOUD?page=21
#
# PAGE 21
# self: https://cmr.earthdata.nasa.gov/stac/LPCLOUD
# root: https://cmr.earthdata.nasa.gov/stac/
# collections: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections
# search: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/search
# search: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/search
# conformance: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/conformance
# service-desc: https://api.stacspec.org/v1.0.0-beta.1/openapi.yaml
# service-doc: https://api.stacspec.org/v1.0.0-beta.1/index.html
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VJ121A1D.v002
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VJ121A1N.v002
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VJ121C3.v002
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VJ115A2H.v002
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VJ103MODLL.v021
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VJ109A1.v002
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VJ109H1.v002
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VJ109GA.v002
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VJ109CMG.v002
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VJ114A1.v002
# prev: https://cmr.earthdata.nasa.gov/stac/LPCLOUD?page=20
# next: https://cmr.earthdata.nasa.gov/stac/LPCLOUD?page=22
#
# PAGE 22
# self: https://cmr.earthdata.nasa.gov/stac/LPCLOUD
# root: https://cmr.earthdata.nasa.gov/stac/
# collections: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections
# search: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/search
# search: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/search
# conformance: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/conformance
# service-desc: https://api.stacspec.org/v1.0.0-beta.1/openapi.yaml
# service-doc: https://api.stacspec.org/v1.0.0-beta.1/index.html
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VJ114.v002
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VJ113C1.v002
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VJ113A2.v002
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VJ113A1.v002
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VJ113C2.v002
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VJ113A3.v002
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP21.v002
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP21C2.v002
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP21A2.v002
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP21C1.v002
# prev: https://cmr.earthdata.nasa.gov/stac/LPCLOUD?page=21
# next: https://cmr.earthdata.nasa.gov/stac/LPCLOUD?page=23
#
# PAGE 23
# self: https://cmr.earthdata.nasa.gov/stac/LPCLOUD
# root: https://cmr.earthdata.nasa.gov/stac/
# collections: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections
# search: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/search
# search: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/search
# conformance: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/conformance
# service-desc: https://api.stacspec.org/v1.0.0-beta.1/openapi.yaml
# service-doc: https://api.stacspec.org/v1.0.0-beta.1/index.html
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP21A1D.v002
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP21A1N.v002
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP21C3.v002
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP15A2H.v002
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP03MODLL.v002
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP09A1.v002
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP09H1.v002
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP09GA.v002
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP09CMG.v002
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP14A1.v002
# prev: https://cmr.earthdata.nasa.gov/stac/LPCLOUD?page=22
# next: https://cmr.earthdata.nasa.gov/stac/LPCLOUD?page=24
#
# PAGE 24
# self: https://cmr.earthdata.nasa.gov/stac/LPCLOUD
# root: https://cmr.earthdata.nasa.gov/stac/
# collections: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections
# search: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/search
# search: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/search
# conformance: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/conformance
# service-desc: https://api.stacspec.org/v1.0.0-beta.1/openapi.yaml
# service-doc: https://api.stacspec.org/v1.0.0-beta.1/index.html
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP14.v002
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP13C1.v002
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP13A2.v002
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP13A1.v002
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP13C2.v002
# child: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP13A3.v002
# prev: https://cmr.earthdata.nasa.gov/stac/LPCLOUD?page=23
#
# Last page

# %%
lp_links = lp_cloud['links']
for l in lp_links:
    try:
        print(f"{l['href']} is the {l['title']}.")
    except:
        print(f"{l['href']}")
# Out:
# https://cmr.earthdata.nasa.gov/stac/LPCLOUD is the Provider catalog.
# https://cmr.earthdata.nasa.gov/stac/ is the Root catalog.
# https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections is the Provider Collections.
# https://cmr.earthdata.nasa.gov/stac/LPCLOUD/search is the Provider Item Search.
# https://cmr.earthdata.nasa.gov/stac/LPCLOUD/search is the Provider Item Search.
# https://cmr.earthdata.nasa.gov/stac/LPCLOUD/conformance is the Conformance Classes.
# https://api.stacspec.org/v1.0.0-beta.1/openapi.yaml is the OpenAPI Doc.
# https://api.stacspec.org/v1.0.0-beta.1/index.html is the HTML documentation.
# https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ASTGTM_NUMNC.v003
# https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ASTGTM_NC.v003
# https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ASTGTM.v003
# https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/WaterBalance_Daily_Historical_GRIDMET.v1.5
# https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L2G_CLOUD.v002
# https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L2G_LSTE.v002
# https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L1CG_RAD.v002
# https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L1B_ATT.v002
# https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L2_CLOUD.v002
# https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L1B_GEO.v002
# https://cmr.earthdata.nasa.gov/stac/LPCLOUD?page=2

# %%
lp_collections = [l['href'] for l in lp_links if l['rel'] == 'collections'][0] # Set collections endpoint to variable
collections_response = r.get(f"{lp_collections}").json()
print(f"This collection contains {collections_response['description']} ({len(collections_response['collections'])} available).")
print("Here's our titles:")
for c in collections_response['collections']:
    print(c['title'])
# Out:
# This collection contains All collections provided by LPCLOUD (10 available).
# Here's our titles:
# ASTER Global Digital Elevation Model Attributes NetCDF V003
# ASTER Global Digital Elevation Model NetCDF V003
# ASTER Global Digital Elevation Model V003
# Daily Historical Water Balance Products for the CONUS
# ECOSTRESS Gridded Cloud Mask Instantaneous L2 Global 70 m V002
# ECOSTRESS Gridded Land Surface Temperature and Emissivity Instantaneous L2 Global 70 m V002
# ECOSTRESS Gridded Top of Atmosphere Calibrated Radiance Instantaneous L1C Global 70 m V002
# ECOSTRESS Swath Attitude and Ephemeris Instantaneous L1B Global V002
# ECOSTRESS Swath Cloud Mask Instantaneous L2 Global 70 m V002
# ECOSTRESS Swath Geolocation Instantaneous L1B Global 70 m V002

# %% [markdown]
# Turns out NASA paginates their APIs. Incredibly annoying.
#
# I'm just gonna skip to the good part and go to the actual HLS data - https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30.v2.0
# This was on page 3. That's why I was so confused trying to find it.

# %%
hls_data = r.get('https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30.v2.0').json()
for s in hls_data: print(f"{s}: {hls_data[s]}")
for s in hls_data['links']: print(f"{s['href']} is the {s['title']}.")
hls_data['extent']
# Out:
# id: HLSL30.v2.0
# stac_version: 1.0.0
# license: not-provided
# title: HLS Landsat Operational Land Imager Surface Reflectance and TOA Brightness Daily Global 30m v2.0
# type: Collection
# description: The Harmonized Landsat Sentinel-2 (HLS) project provides consistent surface reflectance (SR) and top of atmosphere (TOA) brightness data from a virtual constellation of satellite sensors. The Operational Land Imager (OLI) is housed aboard the joint NASA/USGS Landsat 8 and Landsat 9 satellites, while the Multi-Spectral Instrument (MSI) is mounted aboard Europe’s Copernicus Sentinel-2A and Sentinel-2B satellites. The combined measurement enables global observations of the land every 2–3 days at 30-meter (m) spatial resolution. The HLS project uses a set of algorithms to obtain seamless products from OLI and MSI that include atmospheric correction, cloud and cloud-shadow masking, spatial co-registration and common gridding, illumination and view angle normalization, and spectral bandpass adjustment.
#
# The HLSL30 product provides 30-m Nadir Bidirectional Reflectance Distribution Function (BRDF)-Adjusted Reflectance (NBAR) and is derived from Landsat 8/9 OLI data products. The HLSS30 and HLSL30 products are gridded to the same resolution and Military Grid Reference System (MGRS)(https://hls.gsfc.nasa.gov/products-description/tiling-system/) tiling system, and thus are “stackable” for time series analysis.
#
# The HLSL30 product is provided in Cloud Optimized GeoTIFF (COG) format, and each band is distributed as a separate file. There are 11 bands included in the HLSL30 product along with one quality assessment (QA) band and four angle bands. See the User Guide for a more detailed description of the individual bands provided in the HLSL30 product.
# links: [{'rel': 'self', 'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30.v2.0', 'title': 'Info about this collection', 'type': 'application/json'}, {'rel': 'root', 'href': 'https://cmr.earthdata.nasa.gov/stac', 'title': 'Root catalog', 'type': 'application/json'}, {'rel': 'parent', 'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD', 'title': 'Parent catalog', 'type': 'application/json'}, {'rel': 'items', 'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30.v2.0/items', 'title': 'Granules in this collection', 'type': 'application/json'}, {'rel': 'about', 'href': 'https://cmr.earthdata.nasa.gov/search/concepts/C2021957657-LPCLOUD.html', 'title': 'HTML metadata for collection', 'type': 'text/html'}, {'rel': 'via', 'href': 'https://cmr.earthdata.nasa.gov/search/concepts/C2021957657-LPCLOUD.json', 'title': 'CMR JSON metadata for collection', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30.v2.0/2013', 'title': '2013 catalog', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30.v2.0/2014', 'title': '2014 catalog', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30.v2.0/2015', 'title': '2015 catalog', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30.v2.0/2016', 'title': '2016 catalog', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30.v2.0/2017', 'title': '2017 catalog', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30.v2.0/2018', 'title': '2018 catalog', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30.v2.0/2019', 'title': '2019 catalog', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30.v2.0/2020', 'title': '2020 catalog', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30.v2.0/2021', 'title': '2021 catalog', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30.v2.0/2022', 'title': '2022 catalog', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30.v2.0/2023', 'title': '2023 catalog', 'type': 'application/json'}]
# extent: {'spatial': {'bbox': [[-180, -90, 180, 90]]}, 'temporal': {'interval': [['2013-04-11T00:00:00.000Z', None]]}}
# https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30.v2.0 is the Info about this collection.
# https://cmr.earthdata.nasa.gov/stac is the Root catalog.
# https://cmr.earthdata.nasa.gov/stac/LPCLOUD is the Parent catalog.
# https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30.v2.0/items is the Granules in this collection.
# https://cmr.earthdata.nasa.gov/search/concepts/C2021957657-LPCLOUD.html is the HTML metadata for collection.
# https://cmr.earthdata.nasa.gov/search/concepts/C2021957657-LPCLOUD.json is the CMR JSON metadata for collection.
# https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30.v2.0/2013 is the 2013 catalog.
# https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30.v2.0/2014 is the 2014 catalog.
# https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30.v2.0/2015 is the 2015 catalog.
# https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30.v2.0/2016 is the 2016 catalog.
# https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30.v2.0/2017 is the 2017 catalog.
# https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30.v2.0/2018 is the 2018 catalog.
# https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30.v2.0/2019 is the 2019 catalog.
# https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30.v2.0/2020 is the 2020 catalog.
# https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30.v2.0/2021 is the 2021 catalog.
# https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30.v2.0/2022 is the 2022 catalog.
# https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30.v2.0/2023 is the 2023 catalog.
# {'spatial': {'bbox': [[-180, -90, 180, 90]]},
#  'temporal': {'interval': [['2013-04-11T00:00:00.000Z', None]]}}

# %%
data2023 = [s for s in hls_data['links'] if '2023' in s['href']][0]['href']
print(data2023)

data2023_response = r.get(data2023).json()
for s in data2023_response: print(f"{s}: {data2023_response[s]}")
for s in data2023_response['links']: print(f"{s['href']} is the {s['title']}.")
# Out:
# https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30.v2.0/2023
# id: HLSL30.v2.0-2023
# title: HLSL30.v2.0 2023
# description: LPCLOUD sub-catalog for 2023
# links: [{'rel': 'root', 'title': 'Root Catalog', 'href': 'https://cmr.earthdata.nasa.gov/stac', 'type': 'application/json'}, {'rel': 'self', 'title': 'HLSL30.v2.0 2023', 'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30.v2.0/2023', 'type': 'application/json'}, {'rel': 'parent', 'title': 'Parent Catalog', 'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30.v2.0', 'type': 'application/json'}, {'rel': 'child', 'title': '2023-01 catalog', 'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30.v2.0/2023/01', 'type': 'application/json'}, {'rel': 'child', 'title': '2023-02 catalog', 'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30.v2.0/2023/02', 'type': 'application/json'}, {'rel': 'child', 'title': '2023-03 catalog', 'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30.v2.0/2023/03', 'type': 'application/json'}, {'rel': 'child', 'title': '2023-04 catalog', 'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30.v2.0/2023/04', 'type': 'application/json'}, {'rel': 'child', 'title': '2023-05 catalog', 'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30.v2.0/2023/05', 'type': 'application/json'}, {'rel': 'child', 'title': '2023-06 catalog', 'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30.v2.0/2023/06', 'type': 'application/json'}, {'rel': 'child', 'title': '2023-07 catalog', 'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30.v2.0/2023/07', 'type': 'application/json'}, {'rel': 'child', 'title': '2023-08 catalog', 'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30.v2.0/2023/08', 'type': 'application/json'}, {'rel': 'child', 'title': '2023-09 catalog', 'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30.v2.0/2023/09', 'type': 'application/json'}, {'rel': 'child', 'title': '2023-10 catalog', 'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30.v2.0/2023/10', 'type': 'application/json'}]
# type: Catalog
# stac_version: 1.0.0
# https://cmr.earthdata.nasa.gov/stac is the Root Catalog.
# https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30.v2.0/2023 is the HLSL30.v2.0 2023.
# https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30.v2.0 is the Parent Catalog.
# https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30.v2.0/2023/01 is the 2023-01 catalog.
# https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30.v2.0/2023/02 is the 2023-02 catalog.
# https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30.v2.0/2023/03 is the 2023-03 catalog.
# https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30.v2.0/2023/04 is the 2023-04 catalog.
# https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30.v2.0/2023/05 is the 2023-05 catalog.
# https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30.v2.0/2023/06 is the 2023-06 catalog.
# https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30.v2.0/2023/07 is the 2023-07 catalog.
# https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30.v2.0/2023/08 is the 2023-08 catalog.
# https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30.v2.0/2023/09 is the 2023-09 catalog.
# https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30.v2.0/2023/10 is the 2023-10 catalog.

# %% [markdown]
# You see that ID? HLSL30.v2.0-2023? That's the ID we need to get the data.

# %%
data23_10 = [s for s in data2023_response['links'] if '2023/10' in s['href']][0]['href']
print(data23_10)

data23_10_response = r.get(data23_10).json()
for s in data23_10_response: print(f"{s}: {data23_10_response[s]}")
for s in data23_10_response['links']: print(f"{s['href']} is the {s['title']}.")
# Out:
# https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30.v2.0/2023/10
# id: HLSL30.v2.0-2023-10
# title: HLSL30.v2.0 2023-10
# description: LPCLOUD sub-catalog for 2023-10
# links: [{'rel': 'root', 'title': 'Root Catalog', 'href': 'https://cmr.earthdata.nasa.gov/stac', 'type': 'application/json'}, {'rel': 'self', 'title': 'HLSL30.v2.0 2023-10', 'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30.v2.0/2023/10', 'type': 'application/json'}, {'rel': 'parent', 'title': 'Parent Catalog', 'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30.v2.0/2023', 'type': 'application/json'}, {'rel': 'child', 'title': '2023-10-01 catalog', 'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30.v2.0/2023/10/01', 'type': 'application/json'}, {'rel': 'child', 'title': '2023-10-02 catalog', 'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30.v2.0/2023/10/02', 'type': 'application/json'}, {'rel': 'child', 'title': '2023-10-03 catalog', 'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30.v2.0/2023/10/03', 'type': 'application/json'}, {'rel': 'child', 'title': '2023-10-04 catalog', 'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30.v2.0/2023/10/04', 'type': 'application/json'}, {'rel': 'child', 'title': '2023-10-05 catalog', 'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30.v2.0/2023/10/05', 'type': 'application/json'}]
# type: Catalog
# stac_version: 1.0.0
# https://cmr.earthdata.nasa.gov/stac is the Root Catalog.
# https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30.v2.0/2023/10 is the HLSL30.v2.0 2023-10.
# https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30.v2.0/2023 is the Parent Catalog.
# https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30.v2.0/2023/10/01 is the 2023-10-01 catalog.
# https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30.v2.0/2023/10/02 is the 2023-10-02 catalog.
# https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30.v2.0/2023/10/03 is the 2023-10-03 catalog.
# https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30.v2.0/2023/10/04 is the 2023-10-04 catalog.
# https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30.v2.0/2023/10/05 is the 2023-10-05 catalog.

# %%
data23_10_05 = [s for s in data23_10_response['links'] if '2023/10/05' in s['href']][0]['href']
print(data23_10_05)

data23_10_05_response = r.get(data23_10_05).json()
for s in data23_10_05_response: print(s)
for s in data23_10_05_response['links'][0:10]: print(f"{s['href']} is the {s['title']}.")
print("...")
# Out:
# https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30.v2.0/2023/10/05
# id
# title
# description
# links
# type
# stac_version
# https://cmr.earthdata.nasa.gov/stac is the Root Catalog.
# https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30.v2.0/2023/10/05 is the HLSL30.v2.0 2023-10-05.
# https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30.v2.0/2023/10 is the Parent Catalog.
# https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30.v2.0/items/HLS.L30.T56MNB.2023278T000010.v2.0 is the HLS.L30.T56MNB.2023278T000010.v2.0.
# https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30.v2.0/items/HLS.L30.T56MNA.2023278T000010.v2.0 is the HLS.L30.T56MNA.2023278T000010.v2.0.
# https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30.v2.0/items/HLS.L30.T56MMB.2023278T000010.v2.0 is the HLS.L30.T56MMB.2023278T000010.v2.0.
# https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30.v2.0/items/HLS.L30.T56MMA.2023278T000010.v2.0 is the HLS.L30.T56MMA.2023278T000010.v2.0.
# https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30.v2.0/items/HLS.L30.T56MLB.2023278T000010.v2.0 is the HLS.L30.T56MLB.2023278T000010.v2.0.
# https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30.v2.0/items/HLS.L30.T56MLA.2023278T000034.v2.0 is the HLS.L30.T56MLA.2023278T000034.v2.0.
# https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30.v2.0/items/HLS.L30.T56MNV.2023278T000034.v2.0 is the HLS.L30.T56MNV.2023278T000034.v2.0.
# ...

# %% [markdown]
# Now we've FINALLY gotten to individual grid designators. Let's take the first item we see and see what we can do with it.

# %%
rand_item = [s for s in data23_10_05_response['links'] if 'item' in s['rel']][54]['href']
print(rand_item)

rand_item_response = r.get(rand_item).json()

for s in rand_item_response: print(s)

print(f"""
ID: {rand_item_response['id']}
Date: {rand_item_response['properties']['datetime']}
Captured over: {rand_item_response['bbox']} (Lower Left, Upper Right)
Contains {len(rand_item_response['assets'])} assets
Cloud Cover: {rand_item_response['properties']['eo:cloud_cover']}%
      """)

print("Here are the assets:")
for a in rand_item_response['assets']: print(a)
# Out:
# https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30.v2.0/items/HLS.L30.T55JDL.2023278T000633.v2.0
# type
# id
# stac_version
# stac_extensions
# collection
# geometry
# bbox
# links
# properties
# assets
#
# ID: HLS.L30.T55JDL.2023278T000633.v2.0
# Date: 2023-10-05T00:06:33.161Z
# Captured over: [146.178865, -27.210766, 147.098253, -26.218279] (Lower Left, Upper Right)
# Contains 17 assets
# Cloud Cover: 0%
#
# ['https://stac-extensions.github.io/eo/v1.0.0/schema.json']
# Here are the assets:
# B07
# VAA
# B03
# B11
# VZA
# B01
# B02
# SAA
# Fmask
# B09
# B06
# B04
# B05
# B10
# SZA
# browse
# metadata

# %% [markdown]
# Interesting note: The higher the number, the more cloud cover there was. Not sure if this is just sampling bias or if it's actually a thing.

# %%
print(rand_item_response['assets']['browse'])
print(rand_item_response['assets']['Fmask'])
print(rand_item_response['assets']['B01'])
# Out:
# {'href': 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/HLSL30.020/HLS.L30.T56LKP.2023278T000209.v2.0/HLS.L30.T56LKP.2023278T000209.v2.0.jpg', 'type': 'image/jpeg', 'title': 'Download HLS.L30.T56LKP.2023278T000209.v2.0.jpg'}
# {'href': 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSL30.020/HLS.L30.T56LKP.2023278T000209.v2.0/HLS.L30.T56LKP.2023278T000209.v2.0.Fmask.tif', 'title': 'Download HLS.L30.T56LKP.2023278T000209.v2.0.Fmask.tif'}
# {'href': 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSL30.020/HLS.L30.T56LKP.2023278T000209.v2.0/HLS.L30.T56LKP.2023278T000209.v2.0.B01.tif', 'title': 'Download HLS.L30.T56LKP.2023278T000209.v2.0.B01.tif'}

# %% [markdown]
# So now we know how to get the data. However, we need to be able to query it by location (lat/lon). Luckily, if we back up a bit, one of the LPCLOUD links is a search API. Let's see what we can do with that.

# %%
geometry = {
    "type": "MultiPoint",
	"coordinates": [
		# Ames Research Center
		[
			-122.051522,
			37.406939
		],
		[
			-122.034953,
			37.426095
		]
	]
}

search_params = {
    "collections": ["HLSL30.v2.0"],
	"intersects": geometry,
	"datetime": "2023-10-05T00:00:00Z"
}

search_link = "https://cmr.earthdata.nasa.gov/stac/LPCLOUD/search"
search_response = r.post(search_link, json=search_params).json()
for s in search_response['features'][0]: print(s)
# Out:
# type
# id
# stac_version
# stac_extensions
# collection
# geometry
# bbox
# links
# properties
# assets

# %%
import geoviews as gv

base = gv.tile_sources.EsriImagery.opts(width=500,height=500)

geojson = {
    "type":"FeatureCollection",
    "features":
        [
            {
                "type":"Feature",
                "properties":{},
                "geometry": geometry
            }
        ]
}

area_of_interest = gv.Polygons([geometry]).opts(fill_alpha=0, line_color='red', line_width=2)

base * area_of_interest
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# /Users/ethanhanlon/DocumentsNotICloud/Github-Projects/TerraTracker/temp/hls.ipynb Cell 18 line 1
#       <a href='vscode-notebook-cell:/Users/ethanhanlon/DocumentsNotICloud/Github-Projects/TerraTracker/temp/hls.ipynb#X25sZmlsZQ%3D%3D?line=2'>3</a> base = gv.tile_sources.EsriImagery.opts(width=500,height=500)
#       <a href='vscode-notebook-cell:/Users/ethanhanlon/DocumentsNotICloud/Github-Projects/TerraTracker/temp/hls.ipynb#X25sZmlsZQ%3D%3D?line=4'>5</a> geojson = {
#       <a href='vscode-notebook-cell:/Users/ethanhanlon/DocumentsNotICloud/Github-Projects/TerraTracker/temp/hls.ipynb#X25sZmlsZQ%3D%3D?line=5'>6</a>     "type":"FeatureCollection",
#       <a href='vscode-notebook-cell:/Users/ethanhanlon/DocumentsNotICloud/Github-Projects/TerraTracker/temp/hls.ipynb#X25sZmlsZQ%3D%3D?line=6'>7</a>     "features":
#    (...)
#      <a href='vscode-notebook-cell:/Users/ethanhanlon/DocumentsNotICloud/Github-Projects/TerraTracker/temp/hls.ipynb#X25sZmlsZQ%3D%3D?line=13'>14</a>         ]
#      <a href='vscode-notebook-cell:/Users/ethanhanlon/DocumentsNotICloud/Github-Projects/TerraTracker/temp/hls.ipynb#X25sZmlsZQ%3D%3D?line=14'>15</a> }
# ---> <a href='vscode-notebook-cell:/Users/ethanhanlon/DocumentsNotICloud/Github-Projects/TerraTracker/temp/hls.ipynb#X25sZmlsZQ%3D%3D?line=16'>17</a> area_of_interest = gv.Polygons([geometry]).opts(fill_alpha=0, line_color='red', line_width=2)
#      <a href='vscode-notebook-cell:/Users/ethanhanlon/DocumentsNotICloud/Github-Projects/TerraTracker/temp/hls.ipynb#X25sZmlsZQ%3D%3D?line=18'>19</a> base * area_of_interest
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/geoviews/element/geo.py:113, in _Element.__init__(self, data, kdims, vdims, **kwargs)
#     111 elif isinstance(data, _Element):
#     112     kwargs['crs'] = data.crs
# --> 113 super().__init__(data, kdims=kdims, vdims=vdims, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/holoviews/element/path.py:222, in Contours.__init__(self, data, kdims, vdims, **params)
#     220 def __init__(self, data, kdims=None, vdims=None, **params):
#     221     data = [] if data is None else data
# --> 222     super().__init__(data, kdims=kdims, vdims=vdims, **params)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/holoviews/element/path.py:85, in Path.__init__(self, data, kdims, vdims, **params)
#      82             paths.append(path.data)
#      83     data = paths
# ---> 85 super().__init__(data, kdims=kdims, vdims=vdims, **params)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/holoviews/element/selection.py:24, in SelectionIndexExpr.__init__(self, *args, **kwargs)
#      23 def __init__(self, *args, **kwargs):
# ---> 24     super().__init__(*args, **kwargs)
#      25     self._index_skip = False
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/holoviews/core/data/__init__.py:327, in Dataset.__init__(self, data, kdims, vdims, **kwargs)
#     324 kdims, vdims = kwargs.get('kdims'), kwargs.get('vdims')
#     326 validate_vdims = kwargs.pop('_validate_vdims', True)
# --> 327 initialized = Interface.initialize(type(self), data, kdims, vdims,
#     328                                    datatype=kwargs.get('datatype'))
#     329 (data, self.interface, dims, extra_kws) = initialized
#     330 super().__init__(data, **dict(kwargs, **dict(dims, **extra_kws)))
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/holoviews/core/data/interface.py:253, in Interface.initialize(cls, eltype, data, kdims, vdims, datatype)
#     251     continue
#     252 try:
# --> 253     (data, dims, extra_kws) = interface.init(eltype, data, kdims, vdims)
#     254     break
#     255 except DataError:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/holoviews/core/data/multipath.py:67, in MultiInterface.init(cls, eltype, data, kdims, vdims)
#      64     else:
#      65         datatype = [dt for dt in datatype
#      66                     if hasattr(Interface.interfaces.get(dt), 'geom_type')]
# ---> 67 d, interface, dims, _ = Interface.initialize(eltype, d, kdims, vdims,
#      68                                              datatype=datatype)
#      69 if prev_interface:
#      70     if prev_interface != interface:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/holoviews/core/data/interface.py:267, in Interface.initialize(cls, eltype, data, kdims, vdims, datatype)
#     265         priority_error = f"{intfc.__name__} raised following error:\n\n {e}"
#     266         error = f"{error} {priority_error}"
# --> 267         raise DataError(error, intfc).with_traceback(sys.exc_info()[2])
#     268     raise DataError(error)
#     270 return data, interface, dims, extra_kws
#
# DataError: None of the available storage backends were able to support the supplied data format. DictInterface raised following error:
#
#  Dictionary data not understood, should contain a column per dimension or a mapping between key and value dimension values.
#
# DictInterface expects tabular data, for more information on supported datatypes see http://holoviews.org/user_guide/Tabular_Datasets.html
